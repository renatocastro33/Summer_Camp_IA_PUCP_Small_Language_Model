# %% [markdown]
# # Welcome to Modal notebooks!
#
# Write Python code and collaborate in real time. Your code runs in Modal's
# **serverless cloud**, and anyone in the same workspace can join.
#
# This notebook comes with some common Python libraries installed. Run
# cells with `Shift+Enter`.

# %% [markdown]
# ## 1. Setting the environment

# %%
# Clone the repository
# !git clone https://github.com/karpathy/nanochat.git
# %cd nanochat
# Out:
# Cloning into 'nanochat'...
# remote: Enumerating objects: 989, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 989 (delta 104), reused 51 (delta 51), pack-reused 827 (from 3)
# Receiving objects: 100% (989/989), 1.25 MiB | 24.06 MiB/s, done.
# Resolving deltas: 100% (605/605), done.
# /root/nanochat

# %%
# Set the base directory for artifacts
import os
os.environ['NANOCHAT_BASE_DIR'] = '/content/nanochat_data'
# !mkdir -p $NANOCHAT_BASE_DIR

# Install uv package manager
# !curl -LsSf https://astral.sh/uv/install.sh | sh

# Add uv and cargo to the PATH
os.environ['PATH'] = f"/root/.cargo/bin:/root/.local/bin:{os.environ['PATH']}"

# Create a virtual environment and install dependencies
# !uv venv
# !uv sync
print('-'*40)
print('Environment Set')

# Install Rust/Cargo for the tokenizer
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
print('-'*40)
print('Installed Rust/Cargo')
# Out:
# downloading uv 0.9.24 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /root/.local/bin
#   uv
#   uvx
# everything's installed!
#
# To add $HOME/.local/bin to your PATH, either restart your shell or run:
#
#     source $HOME/.local/bin/env (sh, bash, zsh)
#     source $HOME/.local/bin/env.fish (fish)
# WARN: The following commands are shadowed by other commands in your PATH: uv uvx
# Using CPython 3.10.19
# Creating virtual environment at: .venv
# Resolved 135 packages in 30ms
# ⠙ Preparing packages... (0/120)
# ⠙ Preparing packages... (0/120)
# ⠙ Preparing packages... (0/120)
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------     0 B/434.88 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------     0 B/434.88 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------     0 B/434.88 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------     0 B/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# mpmath               ------------------------------     0 B/523.63 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# mpmath               ------------------------------ 16.00 KiB/523.63 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# mpmath               ------------------------------ 16.00 KiB/523.63 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# mpmath               ------------------------------ 16.00 KiB/523.63 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# mpmath               ------------------------------ 16.00 KiB/523.63 KiB
# ⠙ Preparing packages... (0/120)
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# mpmath               ------------------------------ 16.00 KiB/523.63 KiB
# ⠙ Preparing packages... (0/120)
# prompt-toolkit       ------------------------------ 14.87 KiB/382.26 KiB
# tornado              ------------------------------ 16.00 KiB/434.88 KiB
# pytz                 ------------------------------ 14.88 KiB/497.29 KiB
# mpmath               ------------------------------ 16.00 KiB/523.63 KiB
# huggingface-hub      ------------------------------ 14.87 KiB/548.29 KiB
# setuptools           ------------------------------ 16.00 KiB/1.15 MiB
# pygments             ------------------------------ 16.00 KiB/1.17 MiB
# jedi                 ------------------------------ 16.00 KiB/1.50 MiB
# networkx             ------------------------------ 16.00 KiB/1.64 MiB
# pydantic-core        ------------------------------ 14.90 KiB/1.91 MiB
# hf-xet               ------------------------------ 16.00 KiB/3.04 MiB
# tokenizers           ------------------------------ 14.48 KiB/3.19 MiB
# sympy                ------------------------------ 16.00 KiB/6.01 MiB
# pillow               ------------------------------ 16.00 KiB/6.70 MiB
# pandas               ------------------------------ 16.00 KiB/11.78 MiB
# numpy                ------------------------------ 16.00 KiB/17.40 MiB
# wandb                ------------------------------ 14.91 KiB/18.66 MiB
# scipy                ------------------------------ 16.00 KiB/35.92 MiB
# ⠙ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 14.87 KiB/382.26 KiB
# pydantic                 ------------------------------ 14.88 KiB/434.36 KiB
# tornado                  ------------------------------ 16.00 KiB/434.88 KiB
# datasets                 ------------------------------ 14.91 KiB/483.23 KiB
# safetensors              ------------------------------ 16.00 KiB/495.27 KiB
# pytz                     ------------------------------ 14.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 16.00 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 14.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 16.00 KiB/733.63 KiB
# regex                    ------------------------------ 16.00 KiB/771.42 KiB
# ipython                  ------------------------------ 16.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 71.11 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.89 KiB/932.39 KiB
# rustbpe                  ------------------------------ 16.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 16.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------   998 B/1.14 MiB
# setuptools               ------------------------------ 16.00 KiB/1.15 MiB
# pygments                 ------------------------------ 16.00 KiB/1.17 MiB
# jedi                     ------------------------------ 16.00 KiB/1.50 MiB
# kiwisolver               ------------------------------ 16.00 KiB/1.55 MiB
# aiohttp                  ------------------------------ 16.00 KiB/1.57 MiB
# networkx                 ------------------------------ 16.00 KiB/1.64 MiB
# ⠙ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 30.87 KiB/382.26 KiB
# pydantic                 ------------------------------ 30.88 KiB/434.36 KiB
# tornado                  ------------------------------ 16.00 KiB/434.88 KiB
# datasets                 ------------------------------ 110.91 KiB/483.23 KiB
# safetensors              ------------------------------ 16.00 KiB/495.27 KiB
# pytz                     ------------------------------ 30.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 29.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 30.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 16.00 KiB/733.63 KiB
# regex                    ------------------------------ 128.00 KiB/771.42 KiB
# ipython                  ------------------------------ 16.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 126.91 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 14.89 KiB/932.39 KiB
# rustbpe                  ------------------------------ 16.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 16.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 110.90 KiB/1.14 MiB
# setuptools               ------------------------------ 48.00 KiB/1.15 MiB
# pygments                 ------------------------------ 16.00 KiB/1.17 MiB
# jedi                     ------------------------------ 16.00 KiB/1.50 MiB
# kiwisolver               ------------------------------ 16.00 KiB/1.55 MiB
# aiohttp                  ------------------------------ 16.00 KiB/1.57 MiB
# networkx                 ------------------------------ 32.00 KiB/1.64 MiB
# ⠹ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 46.87 KiB/382.26 KiB
# pydantic                 ------------------------------ 30.88 KiB/434.36 KiB
# tornado                  ------------------------------ 36.19 KiB/434.88 KiB
# datasets                 ------------------------------ 142.81 KiB/483.23 KiB
# safetensors              ------------------------------ 32.00 KiB/495.27 KiB
# pytz                     ------------------------------ 30.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 141.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 46.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 16.00 KiB/733.63 KiB
# regex                    ------------------------------ 176.00 KiB/771.42 KiB
# ipython                  ------------------------------ 16.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 174.91 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 190.89 KiB/932.39 KiB
# rustbpe                  ------------------------------ 176.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 16.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 158.90 KiB/1.14 MiB
# setuptools               ------------------------------ 48.00 KiB/1.15 MiB
# pygments                 ------------------------------ 32.00 KiB/1.17 MiB
# jedi                     ------------------------------ 16.00 KiB/1.50 MiB
# kiwisolver               ------------------------------ 16.00 KiB/1.55 MiB
# aiohttp                  ------------------------------ 173.30 KiB/1.57 MiB
# networkx                 ------------------------------ 32.00 KiB/1.64 MiB
# ⠹ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 46.87 KiB/382.26 KiB
# pydantic                 ------------------------------ 46.88 KiB/434.36 KiB
# tornado                  ------------------------------ 61.28 KiB/434.88 KiB
# datasets                 ------------------------------ 142.81 KiB/483.23 KiB
# safetensors              ------------------------------ 63.75 KiB/495.27 KiB
# pytz                     ------------------------------ 30.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 141.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 62.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 224.00 KiB/733.63 KiB
# regex                    ------------------------------ 224.00 KiB/771.42 KiB
# ipython                  ------------------------------ 31.89 KiB/812.37 KiB
# pyzmq                    ------------------------------ 222.58 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 222.89 KiB/932.39 KiB
# rustbpe                  ------------------------------ 224.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 195.66 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 190.90 KiB/1.14 MiB
# setuptools               ------------------------------ 61.63 KiB/1.15 MiB
# pygments                 ------------------------------ 32.00 KiB/1.17 MiB
# jedi                     ------------------------------ 48.00 KiB/1.50 MiB
# kiwisolver               ------------------------------ 222.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 221.30 KiB/1.57 MiB
# networkx                 ------------------------------ 48.00 KiB/1.64 MiB
# ⠹ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 62.87 KiB/382.26 KiB
# pydantic                 ------------------------------ 62.88 KiB/434.36 KiB
# tornado                  ------------------------------ 93.28 KiB/434.88 KiB
# datasets                 ------------------------------ 201.61 KiB/483.23 KiB
# safetensors              ------------------------------ 223.75 KiB/495.27 KiB
# pytz                     ------------------------------ 46.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 185.97 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 78.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 255.89 KiB/733.63 KiB
# regex                    ------------------------------ 256.00 KiB/771.42 KiB
# ipython                  ------------------------------ 64.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 254.58 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 238.89 KiB/932.39 KiB
# rustbpe                  ------------------------------ 256.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 224.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 222.90 KiB/1.14 MiB
# setuptools               ------------------------------ 61.63 KiB/1.15 MiB
# pygments                 ------------------------------ 60.41 KiB/1.17 MiB
# jedi                     ------------------------------ 63.97 KiB/1.50 MiB
# kiwisolver               ------------------------------ 254.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 253.30 KiB/1.57 MiB
# networkx                 ------------------------------ 63.60 KiB/1.64 MiB
# ⠹ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 90.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 126.88 KiB/434.36 KiB
# tornado                  ------------------------------ 157.28 KiB/434.88 KiB
# datasets                 ------------------------------ 236.73 KiB/483.23 KiB
# safetensors              ------------------------------ 271.41 KiB/495.27 KiB
# pytz                     ------------------------------ 46.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 217.97 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 110.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 288.00 KiB/733.63 KiB
# regex                    ------------------------------ 320.00 KiB/771.42 KiB
# ipython                  ------------------------------ 96.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 286.91 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 270.89 KiB/932.39 KiB
# rustbpe                  ------------------------------ 288.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 264.94 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 270.90 KiB/1.14 MiB
# setuptools               ------------------------------ 61.63 KiB/1.15 MiB
# pygments                 ------------------------------ 76.41 KiB/1.17 MiB
# jedi                     ------------------------------ 63.97 KiB/1.50 MiB
# kiwisolver               ------------------------------ 315.28 KiB/1.55 MiB
# aiohttp                  ------------------------------ 317.30 KiB/1.57 MiB
# networkx                 ------------------------------ 111.60 KiB/1.64 MiB
# ⠸ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 90.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 158.88 KiB/434.36 KiB
# tornado                  ------------------------------ 189.17 KiB/434.88 KiB
# datasets                 ------------------------------ 252.73 KiB/483.23 KiB
# safetensors              ------------------------------ 296.24 KiB/495.27 KiB
# pytz                     ------------------------------ 46.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 253.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 222.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 320.00 KiB/733.63 KiB
# regex                    ------------------------------ 336.00 KiB/771.42 KiB
# ipython                  ------------------------------ 112.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 305.94 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 334.89 KiB/932.39 KiB
# rustbpe                  ------------------------------ 320.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 288.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 286.90 KiB/1.14 MiB
# setuptools               ------------------------------ 77.63 KiB/1.15 MiB
# pygments                 ------------------------------ 92.41 KiB/1.17 MiB
# jedi                     ------------------------------ 79.97 KiB/1.50 MiB
# kiwisolver               ------------------------------ 334.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 320.91 KiB/1.57 MiB
# networkx                 ------------------------------ 111.60 KiB/1.64 MiB
# ⠸ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 90.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 158.88 KiB/434.36 KiB
# tornado                  ------------------------------ 269.28 KiB/434.88 KiB
# datasets                 ------------------------------ 268.73 KiB/483.23 KiB
# safetensors              ------------------------------ 335.67 KiB/495.27 KiB
# pytz                     ------------------------------ 46.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 269.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 241.32 KiB/548.29 KiB
# pyyaml                   ------------------------------ 352.00 KiB/733.63 KiB
# regex                    ------------------------------ 384.00 KiB/771.42 KiB
# ipython                  ------------------------------ 139.06 KiB/812.37 KiB
# pyzmq                    ------------------------------ 350.91 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 366.89 KiB/932.39 KiB
# rustbpe                  ------------------------------ 352.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 319.49 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 329.58 KiB/1.14 MiB
# setuptools               ------------------------------ 77.63 KiB/1.15 MiB
# pygments                 ------------------------------ 108.41 KiB/1.17 MiB
# jedi                     ------------------------------ 95.87 KiB/1.50 MiB
# kiwisolver               ------------------------------ 366.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 368.91 KiB/1.57 MiB
# networkx                 ------------------------------ 127.60 KiB/1.64 MiB
# ⠸ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 106.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 174.88 KiB/434.36 KiB
# tornado                  ------------------------------ 269.28 KiB/434.88 KiB
# datasets                 ------------------------------ 286.91 KiB/483.23 KiB
# safetensors              ------------------------------ 351.75 KiB/495.27 KiB
# pytz                     ------------------------------ 62.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 317.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 257.32 KiB/548.29 KiB
# pyyaml                   ------------------------------ 400.00 KiB/733.63 KiB
# regex                    ------------------------------ 422.20 KiB/771.42 KiB
# ipython                  ------------------------------ 192.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 382.81 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 408.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 389.60 KiB/1.03 MiB
# tiktoken                 ------------------------------ 352.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 366.90 KiB/1.14 MiB
# setuptools               ------------------------------ 109.63 KiB/1.15 MiB
# pygments                 ------------------------------ 119.45 KiB/1.17 MiB
# jedi                     ------------------------------ 111.87 KiB/1.50 MiB
# kiwisolver               ------------------------------ 414.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 413.30 KiB/1.57 MiB
# networkx                 ------------------------------ 141.13 KiB/1.64 MiB
# ⠸ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 106.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 225.58 KiB/434.36 KiB
# tornado                  ------------------------------ 301.28 KiB/434.88 KiB
# datasets                 ------------------------------ 302.91 KiB/483.23 KiB
# safetensors              ------------------------------ 399.75 KiB/495.27 KiB
# pytz                     ------------------------------ 62.88 KiB/497.29 KiB
# mpmath                   ------------------------------ 365.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 270.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 448.00 KiB/733.63 KiB
# regex                    ------------------------------ 448.00 KiB/771.42 KiB
# ipython                  ------------------------------ 240.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 420.75 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 472.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 432.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 384.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 392.56 KiB/1.14 MiB
# setuptools               ------------------------------ 136.44 KiB/1.15 MiB
# pygments                 ------------------------------ 220.41 KiB/1.17 MiB
# jedi                     ------------------------------ 127.87 KiB/1.50 MiB
# kiwisolver               ------------------------------ 441.64 KiB/1.55 MiB
# aiohttp                  ------------------------------ 445.30 KiB/1.57 MiB
# networkx                 ------------------------------ 173.13 KiB/1.64 MiB
# ⠼ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 122.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 257.58 KiB/434.36 KiB
# tornado                  ------------------------------ 301.28 KiB/434.88 KiB
# datasets                 ------------------------------ 302.91 KiB/483.23 KiB
# safetensors              ------------------------------ 418.24 KiB/495.27 KiB
# pytz                     ------------------------------ 107.50 KiB/497.29 KiB
# mpmath                   ------------------------------ 410.71 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 286.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 471.23 KiB/733.63 KiB
# regex                    ------------------------------ 496.00 KiB/771.42 KiB
# ipython                  ------------------------------ 255.89 KiB/812.37 KiB
# pyzmq                    ------------------------------ 452.75 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 504.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 464.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 416.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 440.56 KiB/1.14 MiB
# setuptools               ------------------------------ 168.44 KiB/1.15 MiB
# pygments                 ------------------------------ 284.41 KiB/1.17 MiB
# jedi                     ------------------------------ 143.97 KiB/1.50 MiB
# kiwisolver               ------------------------------ 478.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 477.30 KiB/1.57 MiB
# networkx                 ------------------------------ 189.13 KiB/1.64 MiB
# ⠼ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 122.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 270.88 KiB/434.36 KiB
# tornado                  ------------------------------ 333.28 KiB/434.88 KiB
# datasets                 ------------------------------ 318.91 KiB/483.23 KiB
# safetensors              ------------------------------ 463.75 KiB/495.27 KiB
# pytz                     ------------------------------ 107.50 KiB/497.29 KiB
# mpmath                   ------------------------------ 410.71 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 302.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 494.78 KiB/733.63 KiB
# regex                    ------------------------------ 528.00 KiB/771.42 KiB
# ipython                  ------------------------------ 287.89 KiB/812.37 KiB
# pyzmq                    ------------------------------ 472.56 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 536.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 496.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 448.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 472.56 KiB/1.14 MiB
# setuptools               ------------------------------ 184.44 KiB/1.15 MiB
# pygments                 ------------------------------ 316.41 KiB/1.17 MiB
# jedi                     ------------------------------ 175.97 KiB/1.50 MiB
# kiwisolver               ------------------------------ 510.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 525.30 KiB/1.57 MiB
# networkx                 ------------------------------ 223.60 KiB/1.64 MiB
# ⠼ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 138.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 283.90 KiB/434.36 KiB
# tornado                  ------------------------------ 365.28 KiB/434.88 KiB
# datasets                 ------------------------------ 318.91 KiB/483.23 KiB
# safetensors              ------------------------------ 495.27 KiB/495.27 KiB
# pytz                     ------------------------------ 107.50 KiB/497.29 KiB
# mpmath                   ------------------------------ 445.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 334.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 528.00 KiB/733.63 KiB
# regex                    ------------------------------ 560.00 KiB/771.42 KiB
# ipython                  ------------------------------ 304.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 533.75 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 536.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 560.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 480.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 520.56 KiB/1.14 MiB
# setuptools               ------------------------------ 184.44 KiB/1.15 MiB
# pygments                 ------------------------------ 348.41 KiB/1.17 MiB
# jedi                     ------------------------------ 175.97 KiB/1.50 MiB
# kiwisolver               ------------------------------ 558.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 573.30 KiB/1.57 MiB
# networkx                 ------------------------------ 239.60 KiB/1.64 MiB
# ⠼ Preparing packages... (0/120)
# prompt-toolkit           ------------------------------ 138.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 283.90 KiB/434.36 KiB
# tornado                  ------------------------------ 365.28 KiB/434.88 KiB
# datasets                 ------------------------------ 318.91 KiB/483.23 KiB
# pytz                     ------------------------------ 107.50 KiB/497.29 KiB
# mpmath                   ------------------------------ 477.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 334.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 544.00 KiB/733.63 KiB
# regex                    ------------------------------ 576.00 KiB/771.42 KiB
# ipython                  ------------------------------ 304.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 549.75 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 549.87 KiB/932.39 KiB
# rustbpe                  ------------------------------ 560.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 496.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 536.56 KiB/1.14 MiB
# setuptools               ------------------------------ 184.44 KiB/1.15 MiB
# pygments                 ------------------------------ 348.41 KiB/1.17 MiB
# jedi                     ------------------------------ 175.97 KiB/1.50 MiB
# kiwisolver               ------------------------------ 574.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 589.30 KiB/1.57 MiB
# networkx                 ------------------------------ 239.60 KiB/1.64 MiB
# pydantic-core            ------------------------------ 541.51 KiB/1.91 MiB
# ⠼ Preparing packages... (0/120)
# pytest                   ------------------------------     0 B/357.18 KiB
# prompt-toolkit           ------------------------------ 138.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 283.90 KiB/434.36 KiB
# tornado                  ------------------------------ 381.28 KiB/434.88 KiB
# datasets                 ------------------------------ 334.91 KiB/483.23 KiB
# pytz                     ------------------------------ 107.50 KiB/497.29 KiB
# mpmath                   ------------------------------ 509.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 366.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 562.95 KiB/733.63 KiB
# regex                    ------------------------------ 596.04 KiB/771.42 KiB
# ipython                  ------------------------------ 336.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 565.75 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 600.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 592.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 516.51 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 567.16 KiB/1.14 MiB
# setuptools               ------------------------------ 189.63 KiB/1.15 MiB
# pygments                 ------------------------------ 348.41 KiB/1.17 MiB
# jedi                     ------------------------------ 191.97 KiB/1.50 MiB
# kiwisolver               ------------------------------ 590.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 590.80 KiB/1.57 MiB
# networkx                 ------------------------------ 239.60 KiB/1.64 MiB
# ⠴ Preparing packages... (1/120)
# pytest                   ------------------------------ 16.00 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 154.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 301.41 KiB/434.36 KiB
# tornado                  ------------------------------ 397.28 KiB/434.88 KiB
# datasets                 ------------------------------ 334.91 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# mpmath                   ------------------------------ 509.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 382.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 580.53 KiB/733.63 KiB
# regex                    ------------------------------ 624.00 KiB/771.42 KiB
# ipython                  ------------------------------ 352.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 581.75 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 600.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 640.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 544.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 600.56 KiB/1.14 MiB
# setuptools               ------------------------------ 205.63 KiB/1.15 MiB
# pygments                 ------------------------------ 364.41 KiB/1.17 MiB
# jedi                     ------------------------------ 206.87 KiB/1.50 MiB
# kiwisolver               ------------------------------ 634.15 KiB/1.55 MiB
# aiohttp                  ------------------------------ 637.30 KiB/1.57 MiB
# networkx                 ------------------------------ 271.60 KiB/1.64 MiB
# ⠴ Preparing packages... (1/120)
# pytest                   ------------------------------ 48.00 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 170.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 317.41 KiB/434.36 KiB
# tornado                  ------------------------------ 413.28 KiB/434.88 KiB
# datasets                 ------------------------------ 334.91 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# mpmath                   ------------------------------ 509.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 382.87 KiB/548.29 KiB
# pyyaml                   ------------------------------ 628.53 KiB/733.63 KiB
# regex                    ------------------------------ 688.00 KiB/771.42 KiB
# ipython                  ------------------------------ 352.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 600.56 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 616.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 688.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 592.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 648.56 KiB/1.14 MiB
# setuptools               ------------------------------ 236.13 KiB/1.15 MiB
# pygments                 ------------------------------ 396.41 KiB/1.17 MiB
# jedi                     ------------------------------ 214.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 670.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 685.30 KiB/1.57 MiB
# networkx                 ------------------------------ 271.60 KiB/1.64 MiB
# ⠴ Preparing packages... (1/120)
# pytest                   ------------------------------ 111.42 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 186.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 352.52 KiB/434.36 KiB
# tornado                  ------------------------------ 429.28 KiB/434.88 KiB
# datasets                 ------------------------------ 350.91 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# mpmath                   ------------------------------ 523.63 KiB/523.63 KiB
# huggingface-hub          ------------------------------ 392.56 KiB/548.29 KiB
# pyyaml                   ------------------------------ 667.00 KiB/733.63 KiB
# regex                    ------------------------------ 720.00 KiB/771.42 KiB
# ipython                  ------------------------------ 368.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 616.46 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 632.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 720.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 624.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 696.56 KiB/1.14 MiB
# setuptools               ------------------------------ 253.63 KiB/1.15 MiB
# pygments                 ------------------------------ 412.41 KiB/1.17 MiB
# jedi                     ------------------------------ 230.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 718.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 733.30 KiB/1.57 MiB
# networkx                 ------------------------------ 287.15 KiB/1.64 MiB
# ⠴ Preparing packages... (1/120)
# pytest                   ------------------------------ 111.42 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 187.67 KiB/382.26 KiB
# pydantic                 ------------------------------ 368.52 KiB/434.36 KiB
# tornado                  ------------------------------ 429.28 KiB/434.88 KiB
# datasets                 ------------------------------ 350.91 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# huggingface-hub          ------------------------------ 392.56 KiB/548.29 KiB
# pyyaml                   ------------------------------ 667.00 KiB/733.63 KiB
# regex                    ------------------------------ 720.00 KiB/771.42 KiB
# ipython                  ------------------------------ 368.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 616.46 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 637.58 KiB/932.39 KiB
# rustbpe                  ------------------------------ 720.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 624.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 696.56 KiB/1.14 MiB
# setuptools               ------------------------------ 269.63 KiB/1.15 MiB
# pygments                 ------------------------------ 412.41 KiB/1.17 MiB
# jedi                     ------------------------------ 230.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 718.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 733.30 KiB/1.57 MiB
# networkx                 ------------------------------ 287.15 KiB/1.64 MiB
# pydantic-core            ------------------------------ 701.51 KiB/1.91 MiB
# ⠴ Preparing packages... (1/120)
# pytest                   ------------------------------ 124.72 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 202.98 KiB/382.26 KiB
# pydantic                 ------------------------------ 384.52 KiB/434.36 KiB
# tornado                  ------------------------------ 429.28 KiB/434.88 KiB
# datasets                 ------------------------------ 366.91 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# huggingface-hub          ------------------------------ 408.56 KiB/548.29 KiB
# pyyaml                   ------------------------------ 697.61 KiB/733.63 KiB
# regex                    ------------------------------ 768.00 KiB/771.42 KiB
# ipython                  ------------------------------ 384.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 616.46 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 648.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 752.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 672.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 728.56 KiB/1.14 MiB
# setuptools               ------------------------------ 269.63 KiB/1.15 MiB
# pygments                 ------------------------------ 428.41 KiB/1.17 MiB
# jedi                     ------------------------------ 230.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 750.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 781.30 KiB/1.57 MiB
# networkx                 ------------------------------ 303.15 KiB/1.64 MiB
# pydantic-core            ------------------------------ 738.31 KiB/1.91 MiB
# ⠦ Preparing packages... (2/120)
# sentry-sdk               ------------------------------ 15.89 KiB/355.44 KiB
# pytest                   ------------------------------ 187.79 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 246.83 KiB/382.26 KiB
# pydantic                 ------------------------------ 424.56 KiB/434.36 KiB
# datasets                 ------------------------------ 382.91 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# huggingface-hub          ------------------------------ 408.56 KiB/548.29 KiB
# pyyaml                   ------------------------------ 715.00 KiB/733.63 KiB
# regex                    ------------------------------ 771.42 KiB/771.42 KiB
# ipython                  ------------------------------ 406.22 KiB/812.37 KiB
# pyzmq                    ------------------------------ 616.46 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 664.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 784.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 712.51 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 776.56 KiB/1.14 MiB
# setuptools               ------------------------------ 285.63 KiB/1.15 MiB
# pygments                 ------------------------------ 460.41 KiB/1.17 MiB
# jedi                     ------------------------------ 246.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 798.04 KiB/1.55 MiB
# aiohttp                  ------------------------------ 829.30 KiB/1.57 MiB
# networkx                 ------------------------------ 303.15 KiB/1.64 MiB
# pydantic-core            ------------------------------ 770.31 KiB/1.91 MiB
# ⠦ Preparing packages... (2/120)
# sentry-sdk               ------------------------------ 15.89 KiB/355.44 KiB
# pytest                   ------------------------------ 187.79 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 246.83 KiB/382.26 KiB
# pydantic                 ------------------------------ 424.56 KiB/434.36 KiB
# datasets                 ------------------------------ 382.91 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# huggingface-hub          ------------------------------ 408.56 KiB/548.29 KiB
# pyyaml                   ------------------------------ 715.00 KiB/733.63 KiB
# regex                    ------------------------------ 771.42 KiB/771.42 KiB
# ipython                  ------------------------------ 406.22 KiB/812.37 KiB
# pyzmq                    ------------------------------ 616.46 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 664.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 784.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 712.51 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 776.56 KiB/1.14 MiB
# setuptools               ------------------------------ 301.63 KiB/1.15 MiB
# pygments                 ------------------------------ 460.41 KiB/1.17 MiB
# jedi                     ------------------------------ 246.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 798.04 KiB/1.55 MiB
# aiohttp                  ------------------------------ 829.30 KiB/1.57 MiB
# networkx                 ------------------------------ 303.15 KiB/1.64 MiB
# pydantic-core            ------------------------------ 770.31 KiB/1.91 MiB
# ⠦ Preparing packages... (2/120)
# sentry-sdk               ------------------------------ 15.89 KiB/355.44 KiB
# pytest                   ------------------------------ 187.79 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 246.83 KiB/382.26 KiB
# pydantic                 ------------------------------ 424.56 KiB/434.36 KiB
# datasets                 ------------------------------ 382.91 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# huggingface-hub          ------------------------------ 408.56 KiB/548.29 KiB
# pyyaml                   ------------------------------ 715.00 KiB/733.63 KiB
# ipython                  ------------------------------ 406.22 KiB/812.37 KiB
# pyzmq                    ------------------------------ 616.46 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 664.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 784.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 712.51 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 776.56 KiB/1.14 MiB
# setuptools               ------------------------------ 301.63 KiB/1.15 MiB
# pygments                 ------------------------------ 460.41 KiB/1.17 MiB
# jedi                     ------------------------------ 246.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 798.04 KiB/1.55 MiB
# aiohttp                  ------------------------------ 829.30 KiB/1.57 MiB
# networkx                 ------------------------------ 303.15 KiB/1.64 MiB
# pydantic-core            ------------------------------ 770.31 KiB/1.91 MiB
# debugpy                  ------------------------------ 814.88 KiB/2.94 MiB
# ⠦ Preparing packages... (2/120)
# yarl                     ------------------------------     0 B/318.41 KiB
# tzdata                   ------------------------------     0 B/339.69 KiB
# sentry-sdk               ------------------------------ 31.89 KiB/355.44 KiB
# pytest                   ------------------------------ 207.42 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 262.83 KiB/382.26 KiB
# datasets                 ------------------------------ 392.56 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# huggingface-hub          ------------------------------ 424.56 KiB/548.29 KiB
# pyyaml                   ------------------------------ 731.00 KiB/733.63 KiB
# ipython                  ------------------------------ 416.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 632.46 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 680.56 KiB/932.39 KiB
# rustbpe                  ------------------------------ 800.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 728.29 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 792.56 KiB/1.14 MiB
# setuptools               ------------------------------ 301.63 KiB/1.15 MiB
# pygments                 ------------------------------ 476.41 KiB/1.17 MiB
# jedi                     ------------------------------ 246.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 798.14 KiB/1.55 MiB
# aiohttp                  ------------------------------ 845.30 KiB/1.57 MiB
# networkx                 ------------------------------ 303.15 KiB/1.64 MiB
# pydantic-core            ------------------------------ 797.51 KiB/1.91 MiB
# ⠦ Preparing packages... (2/120)
# yarl                     ------------------------------ 16.00 KiB/318.41 KiB
# tzdata                   ------------------------------ 16.00 KiB/339.69 KiB
# sentry-sdk               ------------------------------ 48.00 KiB/355.44 KiB
# pytest                   ------------------------------ 207.42 KiB/357.18 KiB
# prompt-toolkit           ------------------------------ 270.98 KiB/382.26 KiB
# datasets                 ------------------------------ 392.56 KiB/483.23 KiB
# pytz                     ------------------------------ 123.50 KiB/497.29 KiB
# huggingface-hub          ------------------------------ 424.56 KiB/548.29 KiB
# pyyaml                   ------------------------------ 731.00 KiB/733.63 KiB
# ipython                  ------------------------------ 432.00 KiB/812.37 KiB
# pyzmq                    ------------------------------ 744.56 KiB/834.13 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 696.34 KiB/932.39 KiB
# rustbpe                  ------------------------------ 816.00 KiB/1.03 MiB
# tiktoken                 ------------------------------ 736.00 KiB/1.13 MiB
# nvidia-cufile-cu12       ------------------------------ 808.56 KiB/1.14 MiB
# setuptools               ------------------------------ 317.63 KiB/1.15 MiB
# pygments                 ------------------------------ 476.41 KiB/1.17 MiB
# jedi                     ------------------------------ 246.57 KiB/1.50 MiB
# kiwisolver               ------------------------------ 801.71 KiB/1.55 MiB
# aiohttp                  ------------------------------ 861.30 KiB/1.57 MiB
# networkx                 ------------------------------ 319.15 KiB/1.64 MiB
# pydantic-core            ------------------------------ 813.51 KiB/1.91 MiB
# ⠦ Preparing packages... (2/120)
# ...
# ⠴ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 613.56 MiB/674.02 MiB
# ⠴ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 616.96 MiB/674.02 MiB
# ⠴ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 621.43 MiB/674.02 MiB
# ⠴ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 625.39 MiB/674.02 MiB
# ⠦ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 628.97 MiB/674.02 MiB
# ⠦ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 632.26 MiB/674.02 MiB
# ⠦ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 636.81 MiB/674.02 MiB
# ⠦ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 640.39 MiB/674.02 MiB
# ⠧ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 644.62 MiB/674.02 MiB
# ⠧ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 647.98 MiB/674.02 MiB
# ⠧ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 651.48 MiB/674.02 MiB
# ⠧ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 655.16 MiB/674.02 MiB
# ⠇ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 658.36 MiB/674.02 MiB
# ⠇ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 661.90 MiB/674.02 MiB
# ⠇ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 665.12 MiB/674.02 MiB
# ⠇ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 669.02 MiB/674.02 MiB
# ⠋ Preparing packages... (118/120)
# nvidia-cudnn-cu12        ------------------------------ 672.34 MiB/674.02 MiB
# ⠋ Preparing packages... (118/120)
# ⠋ Preparing packages... (118/120)
# ⠋ Preparing packages... (118/120)
# ⠋ Preparing packages... (118/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠋ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠙ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠹ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠸ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠼ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠴ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠦ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠧ Preparing packages... (119/120)
# ⠇ Preparing packages... (119/120)
# Prepared 120 packages in 1m 10s
# Installed 120 packages in 1.82s
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.15
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anyio==4.10.0
#  + asttokens==3.0.1
#  + async-timeout==5.0.1
#  + attrs==25.3.0
#  + certifi==2025.8.3
#  + charset-normalizer==3.4.3
#  + click==8.2.1
#  + comm==0.2.3
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + datasets==4.0.0
#  + debugpy==1.8.19
#  + decorator==5.2.1
#  + dill==0.3.8
#  + exceptiongroup==1.3.0
#  + executing==2.2.1
#  + fastapi==0.117.1
#  + filelock==3.19.1
#  + fonttools==4.61.1
#  + frozenlist==1.7.0
#  + fsspec==2025.3.0
#  + gitdb==4.0.12
#  + gitpython==3.1.45
#  + h11==0.16.0
#  + hf-xet==1.1.9
#  + huggingface-hub==0.34.4
#  + idna==3.10
#  + iniconfig==2.1.0
#  + ipykernel==7.1.0
#  + ipython==8.37.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jupyter-client==8.7.0
#  + jupyter-core==5.9.1
#  + kernels==0.11.7
#  + kiwisolver==1.4.9
#  + markupsafe==3.0.2
#  + matplotlib==3.10.8
#  + matplotlib-inline==0.2.1
#  + mpmath==1.3.0
#  + multidict==6.6.4
#  + multiprocess==0.70.16
#  + nest-asyncio==1.6.0
#  + networkx==3.4.2
#  + numpy==1.26.4
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.5
#  + nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvshmem-cu12==3.3.20
#  + nvidia-nvtx-cu12==12.8.90
#  + packaging==25.0
#  + pandas==2.3.2
#  + parso==0.8.5
#  + pexpect==4.9.0
#  + pillow==12.1.0
#  + platformdirs==4.4.0
#  + pluggy==1.6.0
#  + prompt-toolkit==3.0.52
#  + propcache==0.3.2
#  + protobuf==6.32.0
#  + psutil==7.1.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==21.0.0
#  + pydantic==2.11.7
#  + pydantic-core==2.33.2
#  + pygments==2.19.2
#  + pyparsing==3.3.1
#  + pytest==8.4.2
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.2.1
#  + pytz==2025.2
#  + pyyaml==6.0.2
#  + pyzmq==27.1.0
#  + regex==2025.9.1
#  + requests==2.32.5
#  + rustbpe==0.1.0
#  + safetensors==0.7.0
#  + scipy==1.15.3
#  + sentry-sdk==2.35.2
#  + setuptools==80.9.0
#  + six==1.17.0
#  + smmap==5.0.2
#  + sniffio==1.3.1
#  + stack-data==0.6.3
#  + starlette==0.48.0
#  + sympy==1.14.0
#  + tabulate==0.9.0
#  + tiktoken==0.11.0
#  + tokenizers==0.22.0
#  + tomli==2.2.1
#  + torch==2.9.0
#  + tornado==6.5.4
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + transformers==4.57.3
#  + triton==3.5.0
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.1
#  + tzdata==2025.2
#  + urllib3==2.5.0
#  + uvicorn==0.36.0
#  + wandb==0.21.3
#  + wcwidth==0.2.14
#  + xxhash==3.5.0
#  + yarl==1.20.1
# ----------------------------------------
# Environment Set
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
# info: latest update on 2025-12-11, rust version 1.92.0 (ded5c06cf 2025-12-08)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-docs'
# info: downloading component 'rust-std'
# info: downloading component 'rustc'
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  20.5 MiB /  20.5 MiB (100 %)   5.0 MiB/s in  3s
# info: installing component 'rust-std'
#  28.0 MiB /  28.0 MiB (100 %)  12.4 MiB/s in  2s
# info: installing component 'rustc'
#  74.3 MiB /  74.3 MiB (100 %)  13.3 MiB/s in  5s
# info: installing component 'rustfmt'
# info: default toolchain set to 'stable-x86_64-unknown-linux-gnu'
#
#   stable-x86_64-unknown-linux-gnu installed - rustc 1.92.0 (ded5c06cf 2025-12-08)
#
#
# Rust is installed now. Great!
#
# To get started you may need to restart your current shell.
# This would reload your PATH environment variable to include
# Cargo's bin directory ($HOME/.cargo/bin).
#
# To configure your current shell, you need to source
# the corresponding env file under $HOME/.cargo.
#
# This is usually done by running one of the following (note the leading DOT):
# . "$HOME/.cargo/env"            # For sh/bash/zsh/ash/dash/pdksh
# source "$HOME/.cargo/env.fish"  # For fish
# source $"($nu.home-path)/.cargo/env.nu"  # For nushell
# ----------------------------------------
# Installed Rust/Cargo

# %% [markdown]
# ## 3. Tokenizer

# %%
from huggingface_hub import hf_hub_download
# Download the specific file and get its local file path
tokenizer_pkl_path = hf_hub_download(repo_id="karpathy/nanochat-d34", filename="tokenizer.pkl")
tokenizer_pt_path = hf_hub_download(repo_id="karpathy/nanochat-d34", filename="token_bytes.pt")
# Out:
# tokenizer.pkl:   0%|          | 0.00/846k [00:00<?, ?B/s]
# token_bytes.pt:   0%|          | 0.00/264k [00:00<?, ?B/s]

# %%
tokenizer_pkl_path
# Out:
# '/root/.cache/huggingface/hub/models--karpathy--nanochat-d34/snapshots/c48357d43863a3a6cdc5f5db5b4ec5964e4192d6/tokenizer.pkl'

# %%
# Copying the file into the correct folder
# !mkdir '../../content/nanochat_data/tokenizer/'
# !cp '/root/.cache/huggingface/hub/models--karpathy--nanochat-d34/snapshots/c48357d43863a3a6cdc5f5db5b4ec5964e4192d6/tokenizer.pkl' '/content/nanochat_data/tokenizer/tokenizer.pkl'
# !cp '/root/.cache/huggingface/hub/models--karpathy--nanochat-d34/snapshots/c48357d43863a3a6cdc5f5db5b4ec5964e4192d6/token_bytes.pt' '/content/nanochat_data/tokenizer/token_bytes.pt'

# %% [markdown]
# ## 4. Downloading SFT Trained Weights

# %% [markdown]
# Because you need almost more than 2 hours for Midtraining and Supervised Fine Tuning

# %%
# Download the specific file and get its local file path
d34_stf_gpt_model_path = hf_hub_download(repo_id="renatocastro33/nanochat-d34-sft", filename="chatsft_checkpoints/d34/model_000669.pt")
d34_sft_gpt_json_path = hf_hub_download(repo_id="renatocastro33/nanochat-d34-sft", filename="chatsft_checkpoints/d34/meta_000669.json")
# Out:
# chatsft_checkpoints/d34/model_000669.pt:   0%|          | 0.00/8.58G [00:00<?, ?B/s]
# meta_000669.json:   0%|          | 0.00/260 [00:00<?, ?B/s]

# %%
d34_stf_gpt_model_path
# Out:
# '/root/.cache/huggingface/hub/models--renatocastro33--nanochat-d34-sft/snapshots/8e0266180c5c395b6f53e6625347370e2db645e7/chatsft_checkpoints/d34/model_000669.pt'

# %%
# !mkdir '../../content/nanochat_data/chatsft_checkpoints/'

# %%
# !mkdir '../../content/nanochat_data/chatsft_checkpoints/d34'

# %%
# !cp '/root/.cache/huggingface/hub/models--renatocastro33--nanochat-d34-sft/snapshots/8e0266180c5c395b6f53e6625347370e2db645e7/chatsft_checkpoints/d34/model_000669.pt' '/content/nanochat_data/chatsft_checkpoints/d34/model_000669.pt'
# !cp '/root/.cache/huggingface/hub/models--renatocastro33--nanochat-d34-sft/snapshots/8e0266180c5c395b6f53e6625347370e2db645e7/chatsft_checkpoints/d34/meta_000669.json' '/content/nanochat_data/chatsft_checkpoints/d34/meta_000669.json'

# %% [markdown]
# ## 5. Inference

# %%
# Chat with the model via the Command Line Interface (CLI)
# !bash -c 'source .venv/bin/activate && python -m scripts.chat_cli -p "Why the sky is blue?"'
# Out:
# Autodetected device type: cuda
# 2026-01-13 00:27:43,076 - nanochat.common - INFO - Distributed world size: 1
# 2026-01-13 00:27:43,146 - nanochat.checkpoint_manager - INFO - No model tag provided, guessing model tag: d34
# 2026-01-13 00:27:43,147 - nanochat.checkpoint_manager - INFO - Loading model from /content/nanochat_data/chatsft_checkpoints/d34 with step 669
# 2026-01-13 00:27:47,968 - nanochat.checkpoint_manager - INFO - Building model with config: {'sequence_len': 2048, 'vocab_size': 65536, 'n_layer': 34, 'n_head': 17, 'n_kv_head': 17, 'n_embd': 2176, 'window_pattern': 'L'}
#
# NanoChat Interactive Mode
# --------------------------------------------------
# Type 'quit' or 'exit' to end the conversation
# Type 'clear' to start a new conversation
# --------------------------------------------------
#
# Assistant: The sky appears blue due to a phenomenon known as Rayleigh scattering, named after the British physicist Lord Rayleigh. When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen and oxygen. These molecules scatter the shorter, blue wavelengths of light more than the longer, red wavelengths.
#
# The blue light is scattered in all directions, but because it travels as shorter waves, it is more easily scattered by the smaller molecules. This is why the sky appears blue, especially during the daytime when the sun is high in the sky. At sunrise and sunset, when the sun is lower in the sky, the light has to travel through more of the atmosphere, which scatters the shorter wavelengths even more, resulting in a reddish or orange hue.
#
# It's worth noting that the sky can appear a range of colors, from deep blues and purples to fiery oranges and reds, depending on the amount of dust, water vapor, and other particles in the atmosphere.<|assistant_end|>

# %%
# Chat with the model via the Command Line Interface (CLI)
# !bash -c 'source .venv/bin/activate && python -m scripts.chat_cli -p "If x = 3, how is 3*x + 5?" --temperature 0.3'
# Out:
# Autodetected device type: cuda
# 2026-01-13 00:30:01,224 - nanochat.common - INFO - Distributed world size: 1
# 2026-01-13 00:30:01,249 - nanochat.checkpoint_manager - INFO - No model tag provided, guessing model tag: d34
# 2026-01-13 00:30:01,249 - nanochat.checkpoint_manager - INFO - Loading model from /content/nanochat_data/chatsft_checkpoints/d34 with step 669
# 2026-01-13 00:30:05,898 - nanochat.checkpoint_manager - INFO - Building model with config: {'sequence_len': 2048, 'vocab_size': 65536, 'n_layer': 34, 'n_head': 17, 'n_kv_head': 17, 'n_embd': 2176, 'window_pattern': 'L'}
#
# NanoChat Interactive Mode
# --------------------------------------------------
# Type 'quit' or 'exit' to end the conversation
# Type 'clear' to start a new conversation
# --------------------------------------------------
#
# Assistant: To evaluate 3*x + 5, we need to follow the order of operations, which states that we should perform any operations inside parentheses first. In this case, we have 3*x. So, we'll multiply 3 by 3 to get 9, and then add 5 to get 14.
#
# Therefore, 3*x + 5 equals 3*(3) + 5, which simplifies to 9 + 5, resulting in 14.<|assistant_end|>

# %%
# Chat with the model via the Command Line Interface (CLI)
# !bash -c 'source .venv/bin/activate && python -m scripts.chat_cli -p "Calculate 5*x + 3 = 13, then x is equal to ?" --temperature 0.2' -
# Out:
# Autodetected device type: cuda
# 2026-01-13 00:30:23,492 - nanochat.common - INFO - Distributed world size: 1
# 2026-01-13 00:30:23,527 - nanochat.checkpoint_manager - INFO - No model tag provided, guessing model tag: d34
# 2026-01-13 00:30:23,527 - nanochat.checkpoint_manager - INFO - Loading model from /content/nanochat_data/chatsft_checkpoints/d34 with step 669
# 2026-01-13 00:30:28,080 - nanochat.checkpoint_manager - INFO - Building model with config: {'sequence_len': 2048, 'vocab_size': 65536, 'n_layer': 34, 'n_head': 17, 'n_kv_head': 17, 'n_embd': 2176, 'window_pattern': 'L'}
#
# NanoChat Interactive Mode
# --------------------------------------------------
# Type 'quit' or 'exit' to end the conversation
# Type 'clear' to start a new conversation
# --------------------------------------------------
#
# Assistant: To solve for x, we need to isolate x on one side of the equation. We can start by subtracting 3 from both sides of the equation, which gives us 5*x = 13 - 3. This simplifies to 5*x = 10.
#
# Next, we divide both sides of the equation by 5 to solve for x, resulting in x = 10 / 5. This simplifies to x = 2.<|assistant_end|>

# %% [markdown]
# ## 6. Deploying in NGROK

# %%
# %uv pip install pyngrok
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 2 packages in 57ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# Prepared 1 package in 9ms
# Installed 1 package in 158ms
#  + pyngrok==7.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyngrok import ngrok
authtoken = "82pQNRYrr19fLeBVzxgnU_7LBDdaEy1z5oEbqw9qKQf"
ngrok.set_auth_token(authtoken)
public_url = ngrok.connect(8000)
print(f'Click to access the Web UI: {public_url}')
# Out:
# Click to access the Web UI: NgrokTunnel: "https://6c0b4c788d7f.ngrok-free.app" -> "http://localhost:8000"
# t=2026-01-11T20:47:47+0000 lvl=warn msg="failed to open private leg" id=f7266d9824a8 privaddr=localhost:8000 err="dial tcp 127.0.0.1:8000: connect: connection refused"
# t=2026-01-11T20:56:10+0000 lvl=warn msg="failed to open private leg" id=614517422a5a privaddr=localhost:8000 err="dial tcp 127.0.0.1:8000: connect: connection refused"
# t=2026-01-11T23:18:38+0000 lvl=warn msg="failed to open private leg" id=8a2ad1aa6ab5 privaddr=localhost:8000 err="dial tcp 127.0.0.1:8000: connect: connection refused"
# t=2026-01-11T23:23:04+0000 lvl=warn msg="failed to open private leg" id=60e659b50b3a privaddr=localhost:8000 err="dial tcp 127.0.0.1:8000: connect: connection refused"
# t=2026-01-11T23:35:58+0000 lvl=warn msg="Stopping forwarder" name=http-8000-6b56b689-738e-4f96-b807-7b8b524e8667 acceptErr="failed to accept connection: Listener closed"

# %%
# !bash -c "source .venv/bin/activate && python -m scripts.chat_web --temperature 0.6 --max-tokens 256 --top-k 50"
# Out:
# Autodetected device type: cuda
# 2026-01-11 23:32:47,984 - nanochat.common - INFO - Distributed world size: 1
# Starting NanoChat Web Server
# Temperature: 0.6, Top-k: 50, Max tokens: 256
# INFO:     Started server process [15312]
# INFO:     Waiting for application startup.
# Loading nanochat models across GPUs...
# Initializing worker pool with 1 GPUs...
# Loading model on GPU 0...
# 2026-01-11 23:32:48,022 - nanochat.checkpoint_manager - INFO - No model tag provided, guessing model tag: d34
# 2026-01-11 23:32:48,022 - nanochat.checkpoint_manager - INFO - Loading model from /content/nanochat_data/chatsft_checkpoints/d34 with step 669
# 2026-01-11 23:32:53,705 - nanochat.checkpoint_manager - INFO - Building model with config: {'sequence_len': 2048, 'vocab_size': 65536, 'n_layer': 34, 'n_head': 17, 'n_kv_head': 17, 'n_embd': 2176}
# All 1 workers initialized!
# Server ready at http://localhost:8000
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     38.253.147.129:0 - "GET / HTTP/1.1" 200 OK
# INFO:     38.253.147.129:0 - "GET /health HTTP/1.1" 200 OK
# 2026-01-11 23:34:03,974 - __main__ - INFO - ====================
# 2026-01-11 23:34:03,974 - __main__ - INFO - [USER]: --top-k 50
# 2026-01-11 23:34:03,974 - __main__ - INFO - --------------------
# INFO:     38.253.147.129:0 - "POST /chat/completions HTTP/1.1" 200 OK
# 2026-01-11 23:34:05,001 - __main__ - INFO - [ASSISTANT] (GPU 0): I'd be happy to help you improve your writing. What do you need help with?
#
# Do you have a piece of writing you'd like me to edit, such as a sentence, paragraph, or full essay? Or are you looking for general editing assistance to make your writing more concise or impactful?
# 2026-01-11 23:34:05,001 - __main__ - INFO - ====================
# 2026-01-11 23:34:16,334 - __main__ - INFO - ====================
# 2026-01-11 23:34:16,334 - __main__ - INFO - [USER]: --top-k 50
# 2026-01-11 23:34:16,334 - __main__ - INFO - [ASSISTANT]: I'd be happy to help you improve your writing. What do you need help with?
#
# Do you have a piece of writing you'd like me to edit, such as a sentence, paragraph, or full essay? Or are you looking for general editing assistance to make your writing more concise or impactful?
# 2026-01-11 23:34:16,334 - __main__ - INFO - [USER]: Calculate 5*x + 3 = 13, then x is equal to ?
# 2026-01-11 23:34:16,334 - __main__ - INFO - --------------------
# INFO:     38.253.147.129:0 - "POST /chat/completions HTTP/1.1" 200 OK
# 2026-01-11 23:34:17,915 - __main__ - INFO - [ASSISTANT] (GPU 0): To solve for x, we'll start by isolating x on one side of the equation. We remove the +3 and 5 from the left side, resulting in 5*x = 13 - 3. Multiplying both sides by 5, we have 5*x = 13 - 9, which simplifies to 5*x = 4.
#
# Now, dividing both sides by 5, we find x = 4 / 5. This simplifies to x = 2. Therefore, x is equal to 2.
# 2026-01-11 23:34:17,916 - __main__ - INFO - ====================
# 2026-01-11 23:34:42,408 - __main__ - INFO - ====================
# 2026-01-11 23:34:42,409 - __main__ - INFO - [USER]: --top-k 50
# 2026-01-11 23:34:42,409 - __main__ - INFO - [ASSISTANT]: I'd be happy to help you improve your writing. What do you need help with?
#
# Do you have a piece of writing you'd like me to edit, such as a sentence, paragraph, or full essay? Or are you looking for general editing assistance to make your writing more concise or impactful?
# 2026-01-11 23:34:42,409 - __main__ - INFO - [USER]: Calculate 5*x + 3 = 13, then x is equal to ?
# 2026-01-11 23:34:42,409 - __main__ - INFO - [ASSISTANT]: To solve for x, we'll start by isolating x on one side of the equation. We remove the +3 and 5 from the left side, resulting in 5*x = 13 - 3. Multiplying both sides by 5, we have 5*x = 13 - 9, which simplifies to 5*x = 4.
#
# Now, dividing both sides by 5, we find x = 4 / 5. This simplifies to x = 2. Therefore, x is equal to 2.
# 2026-01-11 23:34:42,409 - __main__ - INFO - [USER]: 5*x + 3 = 13, then x is equal to ?
# 2026-01-11 23:34:42,409 - __main__ - INFO - --------------------
# INFO:     38.253.147.129:0 - "POST /chat/completions HTTP/1.1" 200 OK
# 2026-01-11 23:34:43,955 - __main__ - INFO - [ASSISTANT] (GPU 0): To solve for x, we'll start by isolating x on one side of the equation. We remove the +3 and 5 from the left side, resulting in 5*x = 13 - 3. Multiplying both sides by 5, we have 5*x = 13 - 9, which simplifies to 5*x = 4.
#
# Now, dividing both sides by 5, we find x = 4 / 5. This simplifies to x = 2. Therefore, x is equal to 2.
# 2026-01-11 23:34:43,956 - __main__ - INFO - ====================
#
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [15312]
